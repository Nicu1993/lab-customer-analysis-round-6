# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, Normalizer, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
#Lab | Customer Analysis Round 5

# %%
data = pd.read_csv('marketing_customer_analysis.csv')
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
#Copy

# %%
data1 = data.copy()

# %%
#Numerical/categorical

# %%
data1.select_dtypes("object")
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
data1.select_dtypes("number")
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
#X-y Split

# %%
X = data1.drop(["Response"], axis=1)
y = data["Response"]

# %%
#Normalize numerical

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
numerical_cols = ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies']
scaler = StandardScaler()
X[numerical_cols] = scaler.fit_transform(X[numerical_cols])

# %%
#Lab | Customer Analysis Round 6

# %%
#One Hot/Label Encoding (categorical)

# %%
categorical_cols = ['State', 'Coverage', 'Education', 'EmploymentStatus', 'Gender', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']
categorical_cols
# Out:
# ['State',
#  'Coverage',
#  'Education',
#  'EmploymentStatus',
#  'Gender',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Vehicle Class',
#  'Vehicle Size']

# %%
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# %%
X_encoded
# Out:
#      Customer  Customer Lifetime Value Effective To Date    Income  \
# 0     BU79786                -0.762878           2/24/11  0.612827
# 1     QZ44356                -0.149245           1/31/11 -1.239617
# 2     AI49188                 0.710636           2/19/11  0.365710
# 3     WW63253                -0.052263           1/20/11 -1.239617
# 4     HB64268                -0.755575            2/3/11  0.203390
# ...       ...                      ...               ...       ...
# 9129  LA72316                 2.241590           2/10/11  1.128558
# 9130  PK87824                -0.714411           2/12/11 -0.528450
# 9131  TD14365                 0.023135            2/6/11 -1.239617
# 9132  UP19263                -0.069935            2/3/11 -0.517356
# 9133  Y167826                -0.784955           2/14/11 -1.239617
#
#      Location Code Marital Status  Monthly Premium Auto  \
# 0         Suburban        Married             -0.703925
# ...

# %%
encoder = OneHotEncoder(drop='first')
encoder
# Out:
# OneHotEncoder(drop='first')

# %%
#Concat DataFrames

# %%
concat = pd.concat([X_encoded, X[numerical_cols]], axis=1)

# %%
concat
# Out:
#      Customer  Customer Lifetime Value Effective To Date    Income  \
# 0     BU79786                -0.762878           2/24/11  0.612827
# 1     QZ44356                -0.149245           1/31/11 -1.239617
# 2     AI49188                 0.710636           2/19/11  0.365710
# 3     WW63253                -0.052263           1/20/11 -1.239617
# 4     HB64268                -0.755575            2/3/11  0.203390
# ...       ...                      ...               ...       ...
# 9129  LA72316                 2.241590           2/10/11  1.128558
# 9130  PK87824                -0.714411           2/12/11 -0.528450
# 9131  TD14365                 0.023135            2/6/11 -1.239617
# 9132  UP19263                -0.069935            2/3/11 -0.517356
# 9133  Y167826                -0.784955           2/14/11 -1.239617
#
#      Location Code Marital Status  Monthly Premium Auto  \
# 0         Suburban        Married             -0.703925
# ...

# %%
#Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_train
# Out:
# 434     Yes
# 4641     No
# 4952    Yes
# 1489     No
# 812      No
#        ...
# 5734     No
# 5191    Yes
# 5390     No
# 860     Yes
# 7270     No
# Name: Response, Length: 6393, dtype: object

# %%
#Apply linear regression

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 scaler.fit(X_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:824, in StandardScaler.fit(self, X, y, sample_weight)
#     822 # Reset internal state before fitting
#     823 self._reset()
# --> 824 return self.partial_fit(X, y, sample_weight)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:861, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     858 self._validate_params()
#     860 first_call = not hasattr(self, "n_samples_seen_")
# --> 861 X = self._validate_data(
#     862     X,
#     863     accept_sparse=("csr", "csc"),
#     864     dtype=FLOAT_DTYPES,
#     865     force_all_finite="allow-nan",
#     866     reset=first_call,
#     867 )
#     868 n_features = X.shape[1]
#     870 if sample_weight is not None:
# ...

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 X_train_scaled = scaler.transform(X_train)
#       2 X_test_scaled = scaler.transform(X_test)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:992, in StandardScaler.transform(self, X, copy)
# ...

# %%
ln = LinearRegression()

# %%
ln.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 ln.fit(X_train_scaled, y_train)
#
# NameError: name 'X_train_scaled' is not defined

# %%
#Model Validation
#Description: #R2. #MSE. #RMSE. #MAE.
#In summary, R2 serves as an indicator of the overall goodness of fit of a model, providing insight into
#how well the independent variables explain the dependent variable. On the other hand, RMSE and MAE focus 
#on the error between predicted and actual values. RMSE highlights larger errors more prominently, 
#while MAE treats all errors equally. It is important to consider these metrics in conjunction to gain 
#a comprehensive understanding of a model's performance and its ability to accurately predict the 
#dependent variable.
